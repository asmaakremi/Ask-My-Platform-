# %%
# !pip install llama-index
# !pip install llama-index-embeddings-huggingface
# %pip install ipython-ngql nebula3-python
# Out:
# Requirement already satisfied: llama-index in c:\users\aai47\poc2\flask-api\lib\site-packages (0.10.52)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.2.7)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.12)
# Requirement already satisfied: llama-index-core==0.10.52.post1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.10.52.post1)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.10)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.13 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.25)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.7)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.27)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\aai47\poc2\flask-api\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.52.post1->llama-index) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (0.27.0)
# Requirement already satisfied: llama-cloud<0.0.7,>=0.0.6 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (0.0.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (1.35.10)
# Requirement already satisfied: pandas in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (4.11.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core==0.10.52.post1->llama-index) (1.16.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.2.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-readers-llama-parse>=0.1.2->llama-index) (0.4.5)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.52.post1->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.52.post1->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.52.post1->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.52.post1->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.52.post1->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.52.post1->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-cloud<0.0.7,>=0.0.6->llama-index-core==0.10.52.post1->llama-index) (2.7.1)
# Requirement already satisfied: anyio in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core==0.10.52.post1->llama-index) (4.3.0)
# Requirement already satisfied: certifi in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core==0.10.52.post1->llama-index) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core==0.10.52.post1->llama-index) (1.0.5)
# Requirement already satisfied: idna in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core==0.10.52.post1->llama-index) (3.7)
# Requirement already satisfied: sniffio in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core==0.10.52.post1->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.52.post1->llama-index) (0.14.0)
# Requirement already satisfied: click in c:\users\aai47\poc2\flask-api\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.52.post1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\aai47\poc2\flask-api\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.52.post1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.52.post1->llama-index) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from openai>=1.1.0->llama-index-core==0.10.52.post1->llama-index) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.52.post1->llama-index) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.52.post1->llama-index) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aai47\poc2\flask-api\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.52.post1->llama-index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\aai47\poc2\flask-api\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core==0.10.52.post1->llama-index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.52.post1->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from dataclasses-json->llama-index-core==0.10.52.post1->llama-index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pandas->llama-index-core==0.10.52.post1->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pandas->llama-index-core==0.10.52.post1->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pandas->llama-index-core==0.10.52.post1->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from anyio->httpx->llama-index-core==0.10.52.post1->llama-index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.52.post1->llama-index) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core==0.10.52.post1->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core==0.10.52.post1->llama-index) (2.18.2)
# Requirement already satisfied: six>=1.5 in c:\users\aai47\poc2\flask-api\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.52.post1->llama-index) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: llama-index-embeddings-huggingface in c:\users\aai47\poc2\flask-api\lib\site-packages (0.2.2)
# Requirement already satisfied: huggingface-hub>=0.19.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.23.4)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-embeddings-huggingface) (0.10.52.post1)
# Requirement already satisfied: sentence-transformers>=2.6.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-embeddings-huggingface) (3.0.1)
# Requirement already satisfied: filelock in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.1)
# Requirement already satisfied: requests in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.11.0)
# Requirement already satisfied: aiohttp in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.9.5)
# Requirement already satisfied: minijinja>=1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\aai47\poc2\flask-api\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.0.31)
# Requirement already satisfied: dataclasses-json in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: llama-cloud<0.0.7,>=0.0.6 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.0.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.35.10)
# Requirement already satisfied: pandas in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (10.3.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.42.3)
# Requirement already satisfied: torch>=1.11.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.3.1)
# Requirement already satisfied: scikit-learn in c:\users\aai47\poc2\flask-api\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.0)
# Requirement already satisfied: scipy in c:\users\aai47\poc2\flask-api\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in c:\users\aai47\poc2\flask-api\lib\site-packages (from llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.7.1)
# Requirement already satisfied: anyio in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (4.3.0)
# Requirement already satisfied: certifi in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.5)
# Requirement already satisfied: idna in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.7)
# Requirement already satisfied: sniffio in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aai47\poc2\flask-api\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: click in c:\users\aai47\poc2\flask-api\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in c:\users\aai47\poc2\flask-api\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aai47\poc2\flask-api\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.26.18)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\aai47\poc2\flask-api\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.0.3)
# Requirement already satisfied: sympy in c:\users\aai47\poc2\flask-api\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.12.1)
# Requirement already satisfied: jinja2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\aai47\poc2\flask-api\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.4.6)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\aai47\poc2\flask-api\lib\site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.1)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\aai47\poc2\flask-api\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\aai47\poc2\flask-api\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2021.13.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\aai47\poc2\flask-api\lib\site-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.18.2)
# Requirement already satisfied: six>=1.5 in c:\users\aai47\poc2\flask-api\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\aai47\poc2\flask-api\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from typing import Optional, List, Mapping, Any

from llama_index.core import SimpleDirectoryReader, SummaryIndex
from llama_index.core.callbacks import CallbackManager
from llama_index.core.llms import (
    CustomLLM,
    CompletionResponse,
    CompletionResponseGen,
    LLMMetadata,
)
from llama_index.core.llms.callbacks import llm_completion_callback
from llama_index.core import Settings


class LLM(CustomLLM):
    context_window: int = 3900
    num_output: int = 256
    model_name: str = "custom"
    api_url: str = "http://px101.prod.exalead.com:8110/v1/chat/completions"
    base_prompt=""
    headers = {
        'Authorization': 'Bearer vtYvpB9U+iUQwl0K0MZIj+Uo5u6kilAZJdgHGVBEhNc=',
        'Content-Type': 'application/json'
    }

    @property
    def metadata(self) -> LLMMetadata:
        """Get LLM metadata."""
        return LLMMetadata(
            context_window=self.context_window,
            num_output=self.num_output,
            model_name=self.model_name,
        )

    @llm_completion_callback()
    def complete(self,prompt: str, **kwargs: Any) -> CompletionResponse:
        full_prompt = self.base_prompt + prompt

        messages = [{"role": "user", "content": full_prompt}]
        payload = {
            "model":"meta-llama/Meta-Llama-3-8B-Instruct",
            "messages": messages,
            "max_tokens": 1000,
            "top_p": 1,
            "stop": ["string"],
            "response_format": {
                "type": "text", 
                "temperature": 0.7
            }
        }
        response = requests.post(self.api_url, headers=self.headers, json=payload)
        if response.status_code == 200:
            generated_response = response.json()['choices'][0]['message']['content'].strip()
            return CompletionResponse(text=generated_response)
        else:
            return CompletionResponse(text="Error: API request failed")

    @llm_completion_callback()
    def stream_complete(
        self, prompt: str, **kwargs: Any
    ) -> CompletionResponseGen:
        full_prompt = self.base_prompt + prompt

        messages = [{"role": "user", "content": full_prompt}]
        payload = {
            "model":"meta-llama/Meta-Llama-3-8B-Instruct",
            "messages": messages,
            "max_tokens": 1500,
            "top_p": 1,
            "stop": ["string"],
            "response_format": {
                "type": "text", 
                "temperature": 0.7
            }
        }
        response = requests.post(self.api_url, headers=self.headers, json=payload)
        if response.status_code == 200:
            generated_response = response.json()['choices'][0]['message']['content'].strip()
            for token in generated_response:
                yield CompletionResponse(text=token, delta=token)
        else:
            yield CompletionResponse(text="Error", delta="Error")

# %%
import numpy as np
from typing import List
from llama_index.core.embeddings import BaseEmbedding
import requests

class CustomAPIEmbeddings(BaseEmbedding):
    _api_key: str = "vtYvpB9U+iUQwl0K0MZIj+Uo5u6kilAZJdgHGVBEhNc="
    _embeddings_url: str = "http://px101.prod.exalead.com:8110/v1/embeddings"
    _headers = {
        'Authorization': 'Bearer ' + _api_key,
        'Content-Type': 'application/json'
    }

    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    @classmethod
    def class_name(cls) -> str:
        return "custom_api"

    def _aget_query_embedding(self, query: str) -> List[float]:
        return self._get_embeddings([query], "Represent a document for semantic search:")[0]

    def _get_query_embedding(self, query: str) -> List[float]:
        return self._get_embeddings([query], "Represent a document for semantic search:")[0]

    def _get_text_embedding(self, text: str) -> List[float]:
        return self._get_embeddings([text], "Represent a document for semantic search:")[0]

    def _get_text_embeddings(self, texts: List[str]) -> List[List[float]]:
        return self._get_embeddings(texts, "Represent a document for semantic search:")

    def _get_embeddings(self, texts: List[str], instruction: str) -> List[List[float]]:
        payload = {
            "model": "BAAI/bge-large-en-v1.5",
            "input": texts,
            "encoding_format": "float",
            "instruct": instruction,
        }
        response = requests.post(self._embeddings_url, headers=self._headers, json=payload)
        if response.status_code == 200:
            response_data = response.json()
            embeddings_list = [item['embedding'] for item in response_data['data']]
            return np.array(embeddings_list).tolist()  
        else:
            raise Exception(f"Failed to get embeddings: {response.status_code}, {response.text}")

# %%
from llama_index.core import Settings

Settings.llm = LLM()
# embed_model = CustomAPIEmbeddings(embed_batch_size=2)
Settings.embed_model = "local:BAAI/bge-large-en-v1.5"
# Settings.embed_model = embed_model
Settings.chunk_size = 512

# %%
import os
os.environ["NEBULA_USER"] = "root"
os.environ["NEBULA_PASSWORD"] = "nebula" 
os.environ[
    "NEBULA_ADDRESS"
] = "127.0.0.1:9669"  

space_name = "poc2"
edge_types, rel_prop_names = ["Created","Modified","LastModifiedBy","Responsible","Type"], ["Created","Modified","LastModifiedBy","Responsible","Type"]
tag_prop_names = ["label, comment", "label, comment, version"]  # Comma-separated strings

tags = ["class","ontology"]

# %%
from llama_index.core import StorageContext
from llama_index.graph_stores.nebula import NebulaGraphStore

graph_store = NebulaGraphStore(
    space_name=space_name,
    edge_types=edge_types,
    rel_prop_names=rel_prop_names,
    tags=tags,
    tag_prop_names =tag_prop_names

)
storage_context = StorageContext.from_defaults(graph_store=graph_store)

# %%
# from llama_index.core import SimpleDirectoryReader, KnowledgeGraphIndex
# directory_path = r"C:\Users\AAI47\poc2\flask-api\code\rdf"

# documents = SimpleDirectoryReader(directory_path).load_data()
file_path = r"C:\Users\AAI47\poc2\flask-api\code\rdf\rdf.txt"

reader = SimpleDirectoryReader(input_files=[file_path])
documents = reader.load_data()

# %%
from llama_index.core import KnowledgeGraphIndex
from llama_index.core import download_loader

from llama_index.readers.wikipedia import WikipediaReader


print(documents)
kg_index = KnowledgeGraphIndex.from_documents(
    documents,
    storage_context=storage_context,
    max_triplets_per_chunk=5,
    include_embeddings=True,
)
# Out:
# [Document(id_='d82abb80-af47-4c78-9279-5ecd5b1bbd42', embedding=None, metadata={'file_path': 'C:\\Users\\AAI47\\poc2\\flask-api\\code\\rdf\\rdf.txt', 'file_name': 'rdf.txt', 'file_type': 'text/plain', 'file_size': 3609, 'creation_date': '2024-07-09', 'last_modified_date': '2024-07-09'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\r\n** RDF Data Model and Ontology **\r\n    @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\r\n    @prefix prov: <http://www.w3.org/ns/prov#> .\r\n    @prefix dsqt: <http://www.3ds.com/RDF/Corpus/dsqt/> .\r\n    @prefix ds6w: <http://www.3ds.com/vocabularies/ds6w/> .\r\n    @prefix ds6w1: <http://www.w3.org/2002/07/ds6w/> .\r\n    @prefix owl: <http://www.w3.org/2002/07/owl#> .\r\n    @prefix pno: <http://www.3ds.com/vocabularies/pno/> .\r\n    @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\r\n    @prefix swym: <http://www.3ds.com/vocabularies/swym/> .\r\n    @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\r\n\r\n    ds6w: a owl:Ontology ;\r\n    rdfs:label "6W Vocabulary"@en ;\r\n    rdfs:comment "This ontology defines the DS Corporate vocabulary for 6W tags."^^xsd:string ;\r\n    owl:versionInfo "R2015x" .\r\n\r\n    pno: a owl:Ontology ;\r\n        rdfs:label "3DS PnO Vocabulary"@en ;\r\n        rdfs:comment "This ontology defines the DS People and Organization vocabulary."^^xsd:string ;\r\n        owl:versionInfo "R2016x" .\r\n    \r\n    swym: a owl:Ontology ;\r\n        rdfs:label "3DSwym Vocabulary"@en ;\r\n        rdfs:comment "This ontology defines 3DSwym vocabulary for 6W tags."^^xsd:string ;\r\n        owl:versionInfo "R2016x" .\r\n\r\n    VpmReference: a owl:Class ;\r\n        rdfs:label "VpmReference"@en ;\r\n        rdfs:comment "Physical Product archetype  .Represents physical products within the system and is equivalent to any general product classification. "@en .\r\n\r\n \r\n   pno:Person rdf:type owl:Class ;\r\n        rdfs:label "Person"@en ;\r\n        rdfs:comment "Represents an individual person."@en .\r\n\r\n    physicalProduct:PhysicalProduct rdf:type owl:Class ;\r\n        owl:equivalentClass vpmReference:VPMReference .\r\n \r\n    Document rdf:type owl:Class ;\r\n        rdfs:comment "General class for documents."@en .\r\n\r\n    \r\n    swym:Post rdf:type owl:Class ;\r\n        rdfs:label "Post"@en;\r\n        rdfs:comment "A post within the social collaboration platform."@en .\r\n        \r\n    swym:Idea rdf:type owl:Class ;\r\n        rdfs:label "Post"@en;\r\n        rdfs:comment "an idea within the social collaboration platform."@en .\r\n\r\n\r\n    ds6w:type rdf:type owl:DatatypeProperty;\r\n        rdfs:label "Type"@en;\r\n        rdfs:comment "Specifies the type of object."@en;\r\n        rdfs:domain [ rdf:unionOf ( pno:Person VPMReference Document swym:Post swym:Idea ) ];\r\n        rdfs:range xsd:string.\r\n\r\n    ds6w:modified rdf:type owl:DatatypeProperty;\r\n        rdfs:label "Modified"@en;\r\n        rdfs:comment "Date and time of last modification. Expected format: \'YYYY-MM-DD\'T\'hh:mm:ss\'Z\' (ISO 8601)"@en;\r\n        rdfs:domain [ rdf:unionOf (VPMReference Document  swym:Post swym:Idea ) ];\r\n        rdfs:range xsd:dateTime.\r\n\r\n    ds6w:created rdf:type owl:DatatypeProperty;\r\n        rdfs:label "Created"@en;\r\n        rdfs:comment "Date and time of last modification. Expected format: \'YYYY-MM-DD\'T\'hh:mm:ss\'Z\' (ISO 8601)"@en;\r\n        rdfs:domain [ rdf:unionOf (VPMReference Document swym:Post swym:Idea ) ];\r\n        rdfs:range xsd:dateTime.\r\n\r\n    ds6w:lastModifiedBy rdf:type owl:ObjectProperty;\r\n        rdfs:label "Last Modified By"@en;\r\n        rdfs:comment "The person who did the last modification."@en;\r\n        rdfs:domain [ rdf:unionOf (VPMReference Document  sw ...
# Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: SemanticError: No schema found for `class'
# Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: SemanticError: No schema found for `class'
# Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: SemanticError: No schema found for `class'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\tenacity\__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     477 try:
# --> 478     result = fn(*args, **kwargs)
#     479 except BaseException:  # noqa: B902
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\graph_stores\nebula\nebula_graph_store.py:266, in NebulaGraphStore.execute(self, query, param_map)
#     265 if not result.is_succeeded():
# --> 266     raise ValueError(
#     267         f"Query failed. Query: {query}, Param: {param_map}"
#     268         f"Error message: {result.error_msg()}"
#     269     )
#     270 return result
#
# ValueError: Query failed. Query: INSERT VERTEX `class`(name)   VALUES "Ds6w":("Ds6w");INSERT VERTEX `class`(name)   VALUES "Owl:ontology":("Owl:ontology");INSERT EDGE `Created`(`Created`)   VALUES "Ds6w"->"Owl:ontology"@5675850276216886:("Is");, Param: {}Error message: SemanticError: No schema found for `class'
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# Cell In[40], line 8
#       4 from llama_index.readers.wikipedia import WikipediaReader
#       7 print(documents)
# ----> 8 kg_index = KnowledgeGraphIndex.from_documents(
#       9     documents,
#      10     storage_context=storage_context,
#      11     max_triplets_per_chunk=5,
#      12     include_embeddings=True,
#      13 )
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\indices\base.py:145, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, service_context, **kwargs)
#     136     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     138 nodes = run_transformations(
#     139     documents,  # type: ignore
#     140     transformations,
#     141     show_progress=show_progress,
#     142     **kwargs,
#     143 )
# --> 145 return cls(
#     146     nodes=nodes,
#     147     storage_context=storage_context,
#     148     callback_manager=callback_manager,
#     149     show_progress=show_progress,
#     150     transformations=transformations,
#     151     service_context=service_context,
#     152     **kwargs,
#     153 )
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\indices\knowledge_graph\base.py:99, in KnowledgeGraphIndex.__init__(self, nodes, objects, index_struct, llm, embed_model, storage_context, kg_triple_extract_template, max_triplets_per_chunk, include_embeddings, show_progress, max_object_length, kg_triplet_extract_fn, service_context, **kwargs)
#      94 self._llm = llm or llm_from_settings_or_context(Settings, service_context)
#      95 self._embed_model = embed_model or embed_model_from_settings_or_context(
#      96     Settings, service_context
#      97 )
# ---> 99 super().__init__(
#     100     nodes=nodes,
#     101     index_struct=index_struct,
#     102     service_context=service_context,
#     103     storage_context=storage_context,
#     104     show_progress=show_progress,
#     105     objects=objects,
#     106     **kwargs,
#     107 )
#     109 # TODO: legacy conversion - remove in next release
#     110 if (
#     111     len(self.index_struct.table) > 0
#     112     and isinstance(self.graph_store, SimpleGraphStore)
#     113     and len(self.graph_store._data.graph_dict) == 0
#     114 ):
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\indices\base.py:94, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, service_context, **kwargs)
#      92 if index_struct is None:
#      93     nodes = nodes or []
# ---> 94     index_struct = self.build_index_from_nodes(
#      95         nodes + objects, **kwargs  # type: ignore
#      96     )
#      97 self._index_struct = index_struct
#      98 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\indices\base.py:216, in BaseIndex.build_index_from_nodes(self, nodes, **build_kwargs)
#     214 """Build the index from nodes."""
#     215 self._docstore.add_documents(nodes, allow_update=True)
# --> 216 return self._build_index_from_nodes(nodes, **build_kwargs)
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\indices\knowledge_graph\base.py:211, in KnowledgeGraphIndex._build_index_from_nodes(self, nodes)
#     209 for triplet in triplets:
#     210     subj, _, obj = triplet
# --> 211     self.upsert_triplet(triplet)
#     212     index_struct.add_node([subj, obj], n)
#     214 if self.include_embeddings:
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\indices\knowledge_graph\base.py:259, in KnowledgeGraphIndex.upsert_triplet(self, triplet, include_embeddings)
#     247 def upsert_triplet(
#     248     self, triplet: Tuple[str, str, str], include_embeddings: bool = False
#     249 ) -> None:
#     250     """Insert triplets and optionally embeddings.
#     251
#     252     Used for manual insertion of KG triplets (in the form
#    (...)
#     257         embedding (Any, optional): Embedding option for the triplet. Defaults to None.
#     258     """
# --> 259     self._graph_store.upsert_triplet(*triplet)
#     260     triplet_str = str(triplet)
#     261     if include_embeddings:
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\graph_stores\nebula\nebula_graph_store.py:521, in NebulaGraphStore.upsert_triplet(self, subj, rel, obj)
#     510 dml_query = (
#     511     f"INSERT VERTEX `{entity_type}`(name) "
#     512     f"  VALUES {subj_field}:({QUOTE}{subj}{QUOTE});"
#    (...)
#     518     f"@{rel_hash}:({QUOTE}{rel}{QUOTE});"
#     519 )
#     520 logger.debug(f"upsert_triplet()\nDML query: {dml_query}")
# --> 521 result = self.execute(dml_query)
#     522 assert (
#     523     result and result.is_succeeded()
#     524 ), f"Failed to upsert triplet: {subj} {rel} {obj}, query: {dml_query}"
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\tenacity\__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\tenacity\__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\tenacity\__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\tenacity\__init__.py:419, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     417 if self.reraise:
#     418     raise retry_exc.reraise()
# --> 419 raise retry_exc from fut.exception()
#
# RetryError: RetryError[<Future at 0x1d2951c70d0 state=finished raised ValueError>]

# %%
# print(response)
query_engine = kg_index.as_query_engine(
    include_text=False, response_mode="tree_summarize"
)
response = query_engine.query(
    "write a sparql query from this nlq : search for posts created today ",
)
print(response)
# Out:
# Based on the provided context information and the given knowledge sequence, I'll attempt to write a SPARQL query to answer the query "search for posts created today".
#
# First, let's analyze the given knowledge sequence:
# ```
# ('Ds6w:lastmodifiedby', 'Rdfs:domain', 'Rdf:unionof(vpmreference document swym:post swym:idea')
# ('Swym:post', 'Rdf:type', 'Owl:class')
# ```
# We can infer that:
#
# * `Ds6w:lastmodifiedby` is a property of `Rdf:unionof` (which is a union of `vpmreference`, `document`, `swym:post`, and `swym:idea`)
# * `Swym:post` is a class (of type `Owl:class`)
#
# Now, let's look at the kg_schema:
# ```
# kg_schema: {'schema': "Node properties: [{'tag': 'Class', 'properties': [('label', 'tring'), ('comment', 'tring')]}, {'tag': 'Ontology', 'properties': [('label', 'tring'), ('comment', 'tring'), ('version', 'tring')]}, {'tag': 'entity', 'properties': [('name', 'tring')]}]\nEdge properties: [{'edge': 'Created', 'properties': [('time_details', 'tring')]}, {'edge': 'LastModifiedBy', 'properties': [('person_details', 'tring')]}, {'edge': 'Modified', 'properties': [('time_details', 'tring')]}, {'edge': 'Responsible', 'properties': [('person_details', 'tring')]}, {'edge': 'Type', 'properties': [('property_details', 'tring')]}, {'edge': 'elationship', 'properties': [('relationship', 'tring')]}]\nRelationships: ['(:entity)-[:relationship]->(:entity)']\n"}
# ```
# We can see that there is an edge type `Created` with a property `time_details` of type `

# %%
# from llama_index.core.query_engine import KnowledgeGraphQueryEngine

# from llama_index.core import StorageContext
# from llama_index.graph_stores.nebula import NebulaGraphStore
# from llama_index.core import StorageContext

# query_engine = KnowledgeGraphQueryEngine(
#     storage_context=storage_context,
#     llm=LLM(),
#     verbose=True,
#     graph_query_synthesis_prompt="generate response", 

)
# Out:
#   Cell In[183], line 13
#     )
#     ^
# SyntaxError: unmatched ')'

# %%
# response = query_engine.query(
#     "Tell me about Peter Quill?",
# )
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 response = query_engine.query(
#       2     "Tell me about Peter Quill?",
#       3 )
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\base\base_query_engine.py:52, in BaseQueryEngine.query(self, str_or_query_bundle)
#      50     if isinstance(str_or_query_bundle, str):
#      51         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 52     query_result = self._query(str_or_query_bundle)
#      53 dispatcher.event(
#      54     QueryEndEvent(query=str_or_query_bundle, response=query_result)
#      55 )
#      56 return query_result
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\query_engine\knowledge_graph_query_engine.py:199, in KnowledgeGraphQueryEngine._query(self, query_bundle)
#     195 """Query the graph store."""
#     196 with self.callback_manager.event(
#     197     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     198 ) as query_event:
# --> 199     nodes: List[NodeWithScore] = self._retrieve(query_bundle)
#     201     response = self._response_synthesizer.synthesize(
#     202         query=query_bundle,
#     203         nodes=nodes,
#     204     )
#     206     if self._verbose:
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\query_engine\knowledge_graph_query_engine.py:154, in KnowledgeGraphQueryEngine._retrieve(self, query_bundle)
#     152 def _retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
#     153     """Get nodes for response."""
# --> 154     graph_store_query = self.generate_query(query_bundle.query_str)
#     155     if self._verbose:
#     156         print_text(f"Graph Store Query:\n{graph_store_query}\n", color="yellow")
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\query_engine\knowledge_graph_query_engine.py:132, in KnowledgeGraphQueryEngine.generate_query(self, query_str)
#     129 """Generate a Graph Store Query from a query bundle."""
#     130 # Get the query engine query string
# --> 132 graph_store_query: str = self._llm.predict(
#     133     self._graph_query_synthesis_prompt,
#     134     query_str=query_str,
#     135     schema=self._graph_schema,
#     136 )
#     138 return graph_store_query
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\instrumentation\dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\llama_index\core\llms\llm.py:428, in LLM.predict(self, prompt, **prompt_args)
#     401 @dispatcher.span
#     402 def predict(
#     403     self,
#     404     prompt: BasePromptTemplate,
#     405     **prompt_args: Any,
#     406 ) -> str:
#     407     """Predict for a given prompt.
#     408
#     409     Args:
#    (...)
#     425         ```
#     426     """
#     427     dispatcher.event(
# --> 428         LLMPredictStartEvent(template=prompt, template_args=prompt_args)
#     429     )
#     430     self._log_template_data(prompt, **prompt_args)
#     432     if self.metadata.is_chat_model:
#
# File c:\Users\AAI47\poc2\flask-api\lib\site-packages\pydantic\v1\main.py:341, in BaseModel.__init__(__pydantic_self__, **data)
#     339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
# --> 341     raise validation_error
#     342 try:
#     343     object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for LLMPredictStartEvent
# template
#   value is not a valid dict (type=type_error.dict)
